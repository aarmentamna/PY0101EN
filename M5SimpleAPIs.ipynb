# %% [markdown]
# <a href="https://colab.research.google.com/github/aarmentamna/PY0101EN/blob/main/M5SimpleAPIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple APIs
# ## **Random User and Fruitvice API Examples**

# %% [markdown]
# Example 1: RandomUser API

# %%
# !pip install randomuser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5084 sha256=a7013b19f12d7bda0f5be1798aa2da371c01f0c400904ae147368f02b0802b17
#   Stored in directory: /root/.cache/pip/wheels/21/10/7b/c13bc3e24a3c1000a34554802ad8aa0ff27df56366998a0473
# Successfully built randomuser
# ...

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)
some_list

# %%
name = r.get_full_name()
name
# Out:
# 'Ömür Samancı'

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Sasha Morel   sasha.morel@example.com
# David Ortega   david.ortega@example.com
# Marit Gebert   marit.gebert@example.com
# Kenan Hinna   kenan.hinna@example.com
# Alfred Dunn   alfred.dunn@example.com
# Werner Moor   werner.moor@example.com
# Millie Walker   millie.walker@example.com
# Daniel Gerard   daniel.gerard@example.com
# Norah Renard   norah.renard@example.com
# Emilie Chan   emilie.chan@example.com

# %%
for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/74.jpg
# https://randomuser.me/api/portraits/men/72.jpg
# https://randomuser.me/api/portraits/women/76.jpg
# https://randomuser.me/api/portraits/men/80.jpg
# https://randomuser.me/api/portraits/men/63.jpg
# https://randomuser.me/api/portraits/men/20.jpg
# https://randomuser.me/api/portraits/women/63.jpg
# https://randomuser.me/api/portraits/men/48.jpg
# https://randomuser.me/api/portraits/women/40.jpg
# https://randomuser.me/api/portraits/women/56.jpg

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#               Name  Gender                   City              State  \
# 0       Emma Perry  female  Ballybofey-Stranorlar          Roscommon
# 1     Alberto Long    male               Bathurst         Queensland
# 2      Naomi Overå  female               Skjervøy           Vestfold
# 3       Aiden Wong    male                Clinton             Québec
# 4  Marlene Larsson  female             Elnesvågen          Hordaland
# 5     Giray Eliçin    male                 Amasya           Erzincan
# 6    Deniz Erbulak    male                Bayburt         Kırklareli
# 7      Ella Turner  female                Shannon           Longford
# 8    Gregory James    male             Townsville  Western Australia
# 9   Adham Verdoorn    male                Elshout            Zeeland
#
#                          Email                       DOB  \
# 0       emma.perry@example.com  1976-12-30T14:30:27.644Z
# 1     alberto.long@example.com  1966-03-21T04:25:45.360Z
# ...

# %%
df1 = pd.DataFrame(get_users())  
df1
# Out:
#                    Name  Gender        City           State  \
# 0      Valtteri Haataja    male        Akaa         Lapland
# 1         Sena Kaashoek  female      Notter       Groningen
# 2      Valentina Sheikh  female  Bjervamoen        Telemark
# 3        Joshua Lacroix    male       Brest            Aube
# 4         Carlos Wacker    male  Bad Rodach        Saarland
# 5  Timothy Van der Kolk    male       Empel   Noord-Brabant
# 6    Beatrice Pelletier  female    Cornwall           Yukon
# 7         Niilo Halonen    male      Loimaa  Finland Proper
# 8        Pihla Leinonen  female        Akaa   North Karelia
# 9          Alicja Wulff  female   Lahnstein          Berlin
#
#                             Email                       DOB  \
# 0    valtteri.haataja@example.com  1953-11-25T15:21:17.527Z
# 1       sena.kaashoek@example.com  1983-07-16T21:52:43.281Z
# 2    valentina.sheikh@example.com  1987-01-14T00:34:50.399Z
# 3      joshua.lacroix@example.com  1996-06-20T07:24:22.081Z
# ...

# %% [markdown]
# Example 2: Fruitvice API
# Another, more common way to use APIs, is through requests library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results)
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.7/dist-packages/pandas/__init__.py'>

# %%
df2 = pd.json_normalize(results)
df2
# Out:
#          genus          name  id           family             order  \
# 0        Malus         Apple   6         Rosaceae           Rosales
# 1       Prunus       Apricot  35         Rosaceae           Rosales
# 2         Musa        Banana   1         Musaceae      Zingiberales
# 3        Rubus    Blackberry  64         Rosaceae           Rosales
# 4     Fragaria     Blueberry  33         Rosaceae           Rosales
# 5       Prunus        Cherry   9         Rosaceae              None
# 6        Durio        Durian  60        Malvaceae          Malvales
# 7        Ficus           Fig  68         Moraceae           Rosales
# 8        Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 9        Vitis        Grapes  47         Vitaceae           Vitales
# 10       Malus    GreenApple  72         Rosaceae           Rosales
# 11     Psidium         Guava  37        Myrtaceae          Myrtales
# 12     Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# ...

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %%
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# Exercise 3
# This page contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
#
# Using requests.get("url") function, load your data.

# %%
data2 = requests.get("https://www.fishwatch.gov/api/species")

# %%
results2 = json.loads(data2.text)

# %%
df3 = pd.DataFrame(results2)
df3
# Out:
#                                     Fishery Management  \
# 0    <ul>\n<li><a href="https://www.fisheries.noaa....
# 1    <ul>\n<li><a href="https://www.fisheries.noaa....
# 2    <ul>\n<li>\n<p><a href="https://archive.fisher...
# 3    <ul>\n<li><a href="https://www.fisheries.noaa....
# 4    <ul>\n<li>The states and <a href="https://www....
# ..                                                 ...
# 111  <ul>\n<li><a href="https://www.fisheries.noaa....
# 112  <ul>\n<li><a href="https://www.greateratlantic...
# 113  <ul>\n<li><a href="http://sero.nmfs.noaa.gov/"...
# 114  <ul>\n<li><a href="https://sero.nmfs.noaa.gov/...
# 115  <ul>\n<li>There are two stocks of Atlantic cod...
#
#                                                Habitat  \
# 0                                                 None
# 1    <ul>\n<li>White hake are groundfish, meaning t...
# 2    <ul>\n<li>Atlantic chub mackerel are a schooli...
# 3    <ul>\n<li>Shortfin squid live in deep and shal...
# ...

# %% [markdown]
# PREGUNTAS

# %%
import numpy as np

a=np.array([0,1,0,1,0])
b=np.array([1,0,1,0,1])

c=a*b
c
# Out:
# array([0, 0, 0, 0, 0])

# %%
a=np.array([0,1])
b=np.array([1,0])
np.dot(a,b)
# Out:
# 0

# %%
a=np.array([1,1,1,1,1])
a+10
# Out:
# array([11, 11, 11, 11, 11])
